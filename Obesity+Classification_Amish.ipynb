# %%
#Random Forest algorithm
#replicate findings from Walters et al 2014

# %%
import io, os, sys, types
from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell

import biom
import sklearn
import pandas as pd

# %%
#Amish dataset
text_file = "/home/barbarahe/merged_bmi_mapping_final__original_study_amish_Fraser__.txt"
biom_file = "/home/barbarahe/filtered_otu_table__original_study_amish_Fraser__.biom"

# %%
m = pd.read_csv(text_file, sep="\t")

# %%
m['help'] = m['#SampleID'].apply(str)
m.set_index('help', inplace=True)

# %%
m.index
# Out:
# Index(['1', '6', '16', '18', '32', '35', '53', '54', '60', '64',
#        ...
#        '471', '473', '475', '476', '481', '482', '488', '595', '598', '599'],
#       dtype='object', name='help', length=325)

# %%
m.columns
# Out:
# Index(['#SampleID', 'BarcodeSequence', 'LinkerPrimerSequence', 'BMI',
#        'bmi_group_binned', 'bmi_group_coded', 'original_study',
#        'combined_study_bmi_group', 'PCR_PRIMERS', 'TARGET_SUBFRAGMENT', 'AGE',
#        'ELEVATION', 'LONGITUDE', 'COUNTRY', 'SEQUENCING_METH', 'SAMPLE_CENTER',
#        'Description_duplicate', 'ReversePrimer', 'COLLECTION_DATE', 'SEX',
#        'FAMILY_RELATIONSHIP_GG', 'STUDY_CENTER', 'EXPERIMENT_CENTER',
#        'bmi_group_amish', 'RUN_CENTER', 'LATITUDE', 'Description'],
#       dtype='object')

# %%
m.index
# Out:
# Index(['1', '6', '16', '18', '32', '35', '53', '54', '60', '64',
#        ...
#        '471', '473', '475', '476', '481', '482', '488', '595', '598', '599'],
#       dtype='object', name='help', length=325)

# %%
b= biom.load_table(biom_file)

# %%
#select only samples that fit LEAN OR OBESE
i = m[m.bmi_group_coded != "Overweight"].index
i_2 = m[m.bmi_group_coded != "Overweight"]

i_2.loc[i_2.bmi_group_binned == 3, 'bmi_group_binned'] = 0
i_2
#i_copy = i_2
#print(i_copy)
# Out:
# /home/barbarahe/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#       #SampleID BarcodeSequence   LinkerPrimerSequence   BMI  \
# help
# 1             1        CTCTAGAG  CATGCTGCCTCCCGTAGGAGT  23.5
# 6             6        AGTCGTCA  CATGCTGCCTCCCGTAGGAGT  22.8
# 16           16        AGTGCTCA  CATGCTGCCTCCCGTAGGAGT  21.6
# 18           18        AGACGTCT  CATGCTGCCTCCCGTAGGAGT  23.3
# 32           32        GTCTAGTG  CATGCTGCCTCCCGTAGGAGT  22.4
# 35           35        ACGTACGT  CATGCTGCCTCCCGTAGGAGT  24.9
# 53           53        CTGAGTGT  CATGCTGCCTCCCGTAGGAGT  23.9
# 54           54        GATCTGCA  CATGCTGCCTCCCGTAGGAGT  23.9
# 60           60        CTGAGTGT  CATGCTGCCTCCCGTAGGAGT  24.7
# 64           64        GAGTCTGT  CATGCTGCCTCCCGTAGGAGT  23.6
# 81           81        CACTCTGT  CATGCTGCCTCCCGTAGGAGT  22.2
# 97           97        ACAGACAG  CATGCTGCCTCCCGTAGGAGT  23.5
# 101         101        AGAGACTG  CATGCTGCCTCCCGTAGGAGT  22.9
# 107         107        CATGTGCA  CATGCTGCCTCCCGTAGGAGT  23.9
# 112         112        GTCTCTGT  CATGCTGCCTCCCGTAGGAGT  22.9
# 115         115        GTCTGTGA  CATGCTGCCTCCCGTAGGAGT  23.0
# 124         124        ATGCTACG  CATGCTGCCTCCCGTAGGAGT  19.3
# 132         132        ACTCGTCT  CATGCTGCCTCCCGTAGGAGT  23.3
# 136         136        AGAGACTG  CATGCTGCCTCCCGTAGGAGT  18.5
# 138         138        GTCAGTGT  CATGCTGCCTCCCGTAGGAGT  23.2
# 140         140        ACTGACTG  CATGCTGCCTCCCGTAGGAGT  18.8
# 150         150        CACAGTGT  CATGCTGCCTCCCGTAGGAGT  22.6
# 159         159        CACTCTGT  CATGCTGCCTCCCGTAGGAGT  24.1
# 165         165        CTCTGTGT  CATGCTGCCTCCCGTAGGAGT  24.0
# 177         177        GAGACTGA  CATGCTGCCTCCCGTAGGAGT  20.1
# 180         180        GTAGTGCT  CATGCTGCCTCCCGTAGGAGT  20.6
# 185         185        GAGTCTGT  CATGCTGCCTCCCGTAGGAGT  20.6
# 205         205        CAGTGTGT  CATGCTGCCTCCCGTAGGAGT  20.3
# 214         214        GAGAGTGT  CATGCTGCCTCCCGTAGGAGT  24.6
# 216         216        ACACGTCA  CATGCTGCCTCCCGTAGGAGT  19.8
# ...         ...             ...                    ...   ...
# 380         380        GAGTCTGT  CATGCTGCCTCCCGTAGGAGT  31.7
# 383         383        GTGTCTGA  CATGCTGCCTCCCGTAGGAGT  31.4
# 384         384        GCTATACG  CATGCTGCCTCCCGTAGGAGT  34.6
# 386         386        GAGACTGA  CATGCTGCCTCCCGTAGGAGT  33.8
# 389         389        ACTCACAG  CATGCTGCCTCCCGTAGGAGT  33.4
# 391         391        GTGTCTGA  CATGCTGCCTCCCGTAGGAGT  32.6
# 396         396        GTGTAGAG  CATGCTGCCTCCCGTAGGAGT  31.2
# 402         402        ACGAGATG  CATGCTGCCTCCCGTAGGAGT  33.9
# 403         403        ACTCGTCT  CATGCTGCCTCCCGTAGGAGT  39.4
# 405         405        AGAGACTG  CATGCTGCCTCCCGTAGGAGT  32.6
# 412         412        CGTATACG  CATGCTGCCTCCCGTAGGAGT  42.6
# 414         414        ACTCACAG  CATGCTGCCTCCCGTAGGAGT  30.1
# 417         417        AGACGTCT  CATGCTGCCTCCCGTAGGAGT  32.9
# 422         422        CTCTGTGT  CATGCTGCCTCCCGTAGGAGT  41.1
# 431         431        CGTATACG  CATGCTGCCTCCCGTAGGAGT  32.1
# 438         438        CTCAGTGA  CATGCTGCCTCCCGTAGGAGT  30.7
# 439         439        GACTGTGT  CATGCTGCCTCCCGTAGGAGT  30.4
# 441         441        AGAGCTCT  CATGCTGCCTCCCGTAGGAGT  34.0
# 443         443        CAGACTGT  CATGCTGCCTCCCGTAGGAGT  32.2
# 447         447        CACAGTGT  CATGCTGCCTCCCGTAGGAGT  31.0
# 449         449        CAGAGTGA  CATGCTGCCTCCCGTAGGAGT  31.0
# 450         450        CACTCTGT  CATGCTGCCTCCCGTAGGAGT  34.6
# 456         456        GAGTAGTG  CATGCTGCCTCCCGTAGGAGT  30.5
# 466         466        GTACTGCA  CATGCTGCCTCCCGTAGGAGT  31.8
# 469         469        CGATGCAT  CATGCTGCCTCCCGTAGGAGT  36.3
# 474         474        GCTACGAT  CATGCTGCCTCCCGTAGGAGT  31.3
# 477         477        AGCTACGT  CATGCTGCCTCCCGTAGGAGT  30.4
# 483         483        CAGTAGAG  CATGCTGCCTCCCGTAGGAGT  32.8
# 484         484        AGACACAG  CATGCTGCCTCCCGTAGGAGT  34.3
# 597         597        GATGTGCT  CATGCTGCCTCCCGTAGGAGT  30.2
#
#       bmi_group_binned bmi_group_coded original_study  \
# help
# 1                    1          Normal   amish_Fraser
# 6                    1          Normal   amish_Fraser
# 16                   1          Normal   amish_Fraser
# 18                   1          Normal   amish_Fraser
# 32                   1          Normal   amish_Fraser
# 35                   1          Normal   amish_Fraser
# 53                   1          Normal   amish_Fraser
# 54                   1          Normal   amish_Fraser
# 60                   1          Normal   amish_Fraser
# 64                   1          Normal   amish_Fraser
# 81                   1          Normal   amish_Fraser
# 97                   1          Normal   amish_Fraser
# 101                  1          Normal   amish_Fraser
# 107                  1          Normal   amish_Fraser
# 112                  1          Normal   amish_Fraser
# 115                  1          Normal   amish_Fraser
# 124                  1          Normal   amish_Fraser
# 132                  1          Normal   amish_Fraser
# 136                  1          Normal   amish_Fraser
# 138                  1          Normal   amish_Fraser
# 140                  1          Normal   amish_Fraser
# 150                  1          Normal   amish_Fraser
# 159                  1          Normal   amish_Fraser
# 165                  1          Normal   amish_Fraser
# 177                  1          Normal   amish_Fraser
# 180                  1          Normal   amish_Fraser
# 185                  1          Normal   amish_Fraser
# 205                  1          Normal   amish_Fraser
# 214                  1          Normal   amish_Fraser
# 216                  1          Normal   amish_Fraser
# ...                ...             ...            ...
# 380                  0           Obese   amish_Fraser
# 383                  0           Obese   amish_Fraser
# 384                  0           Obese   amish_Fraser
# 386                  0           Obese   amish_Fraser
# 389                  0           Obese   amish_Fraser
# 391                  0           Obese   amish_Fraser
# 396                  0           Obese   amish_Fraser
# 402                  0           Obese   amish_Fraser
# 403                  0           Obese   amish_Fraser
# 405                  0           Obese   amish_Fraser
# 412                  0           Obese   amish_Fraser
# 414                  0           Obese   amish_Fraser
# 417                  0           Obese   amish_Fraser
# 422                  0           Obese   amish_Fraser
# 431                  0           Obese   amish_Fraser
# 438                  0           Obese   amish_Fraser
# 439                  0           Obese   amish_Fraser
# 441                  0           Obese   amish_Fraser
# 443                  0           Obese   amish_Fraser
# 447                  0           Obese   amish_Fraser
# 449                  0           Obese   amish_Fraser
# 450                  0           Obese   amish_Fraser
# 456                  0           Obese   amish_Fraser
# 466                  0           Obese   amish_Fraser
# 469                  0           Obese   amish_Fraser
# 474                  0           Obese   amish_Fraser
# 477                  0           Obese   amish_Fraser
# 483                  0           Obese   amish_Fraser
# 484                  0           Obese   amish_Fraser
# 597                  0           Obese   amish_Fraser
#
#      combined_study_bmi_group PCR_PRIMERS TARGET_SUBFRAGMENT     ...      \
# help                                                             ...
# 1         Normal_amish_Fraser     no_data                 V2     ...
# 6         Normal_amish_Fraser     no_data                 V2     ...
# 16        Normal_amish_Fraser     no_data                 V2     ...
# 18        Normal_amish_Fraser     no_data                 V2     ...
# 32        Normal_amish_Fraser     no_data                 V2     ...
# 35        Normal_amish_Fraser     no_data                 V2     ...
# 53        Normal_amish_Fraser     no_data                 V2     ...
# 54        Normal_amish_Fraser     no_data                 V2     ...
# 60        Normal_amish_Fraser     no_data                 V2     ...
# 64        Normal_amish_Fraser     no_data                 V2     ...
# 81        Normal_amish_Fraser     no_data                 V2     ...
# 97        Normal_amish_Fraser     no_data                 V2     ...
# 101       Normal_amish_Fraser     no_data                 V2     ...
# 107       Normal_amish_Fraser     no_data                 V2     ...
# 112       Normal_amish_Fraser     no_data                 V2     ...
# 115       Normal_amish_Fraser     no_data                 V2     ...
# 124       Normal_amish_Fraser     no_data                 V2     ...
# 132       Normal_amish_Fraser     no_data                 V2     ...
# 136       Normal_amish_Fraser     no_data                 V2     ...
# 138       Normal_amish_Fraser     no_data                 V2     ...
# 140       Normal_amish_Fraser     no_data                 V2     ...
# 150       Normal_amish_Fraser     no_data                 V2     ...
# 159       Normal_amish_Fraser     no_data                 V2     ...
# 165       Normal_amish_Fraser     no_data                 V2     ...
# 177       Normal_amish_Fraser     no_data                 V2     ...
# 180       Normal_amish_Fraser     no_data                 V2     ...
# 185       Normal_amish_Fraser     no_data                 V2     ...
# 205       Normal_amish_Fraser     no_data                 V2     ...
# 214       Normal_amish_Fraser     no_data                 V2     ...
# 216       Normal_amish_Fraser     no_data                 V2     ...
# ...                       ...         ...                ...     ...
# 380        Obese_amish_Fraser     no_data                 V2     ...
# 383        Obese_amish_Fraser     no_data                 V2     ...
# 384        Obese_amish_Fraser     no_data                 V2     ...
# 386        Obese_amish_Fraser     no_data                 V2     ...
# 389        Obese_amish_Fraser     no_data                 V2     ...
# 391        Obese_amish_Fraser     no_data                 V2     ...
# 396        Obese_amish_Fraser     no_data                 V2     ...
# 402        Obese_amish_Fraser     no_data                 V2     ...
# 403        Obese_amish_Fraser     no_data                 V2     ...
# 405        Obese_amish_Fraser     no_data                 V2     ...
# 412        Obese_amish_Fraser     no_data                 V2     ...
# 414        Obese_amish_Fraser     no_data                 V2     ...
# 417        Obese_amish_Fraser     no_data                 V2     ...
# 422        Obese_amish_Fraser     no_data                 V2     ...
# 431        Obese_amish_Fraser     no_data                 V2     ...
# 438        Obese_amish_Fraser     no_data                 V2     ...
# 439        Obese_amish_Fraser     no_data                 V2     ...
# 441        Obese_amish_Fraser     no_data                 V2     ...
# 443        Obese_amish_Fraser     no_data                 V2     ...
# 447        Obese_amish_Fraser     no_data                 V2     ...
# 449        Obese_amish_Fraser     no_data                 V2     ...
# 450        Obese_amish_Fraser     no_data                 V2     ...
# 456        Obese_amish_Fraser     no_data                 V2     ...
# 466        Obese_amish_Fraser     no_data                 V2     ...
# 469        Obese_amish_Fraser     no_data                 V2     ...
# 474        Obese_amish_Fraser     no_data                 V2     ...
# 477        Obese_amish_Fraser     no_data                 V2     ...
# 483        Obese_amish_Fraser     no_data                 V2     ...
# 484        Obese_amish_Fraser     no_data                 V2     ...
# 597        Obese_amish_Fraser     no_data                 V2     ...
#
#       ReversePrimer COLLECTION_DATE      SEX FAMILY_RELATIONSHIP_GG  \
# help
# 1           no_data         no_data  no_data                no_data
# 6           no_data         no_data  no_data                no_data
# 16          no_data         no_data  no_data                no_data
# 18          no_data         no_data  no_data                no_data
# 32          no_data         no_data  no_data                no_data
# 35          no_data         no_data  no_data                no_data
# 53          no_data         no_data  no_data                no_data
# 54          no_data         no_data  no_data                no_data
# 60          no_data         no_data  no_data                no_data
# 64          no_data         no_data  no_data                no_data
# 81          no_data         no_data  no_data                no_data
# 97          no_data         no_data  no_data                no_data
# 101         no_data         no_data  no_data                no_data
# 107         no_data         no_data  no_data                no_data
# 112         no_data         no_data  no_data                no_data
# 115         no_data         no_data  no_data                no_data
# 124         no_data         no_data  no_data                no_data
# 132         no_data         no_data  no_data                no_data
# 136         no_data         no_data  no_data                no_data
# 138         no_data         no_data  no_data                no_data
# 140         no_data         no_data  no_data                no_data
# 150         no_data         no_data  no_data                no_data
# 159         no_data         no_data  no_data                no_data
# 165         no_data         no_data  no_data                no_data
# 177         no_data         no_data  no_data                no_data
# 180         no_data         no_data  no_data                no_data
# 185         no_data         no_data  no_data                no_data
# 205         no_data         no_data  no_data                no_data
# 214         no_data         no_data  no_data                no_data
# 216         no_data         no_data  no_data                no_data
# ...             ...             ...      ...                    ...
# 380         no_data         no_data  no_data                no_data
# 383         no_data         no_data  no_data                no_data
# 384         no_data         no_data  no_data                no_data
# 386         no_data         no_data  no_data                no_data
# 389         no_data         no_data  no_data                no_data
# 391         no_data         no_data  no_data                no_data
# 396         no_data         no_data  no_data                no_data
# 402         no_data         no_data  no_data                no_data
# 403         no_data         no_data  no_data                no_data
# 405         no_data         no_data  no_data                no_data
# 412         no_data         no_data  no_data                no_data
# 414         no_data         no_data  no_data                no_data
# 417         no_data         no_data  no_data                no_data
# 422         no_data         no_data  no_data                no_data
# 431         no_data         no_data  no_data                no_data
# 438         no_data         no_data  no_data                no_data
# 439         no_data         no_data  no_data                no_data
# 441         no_data         no_data  no_data                no_data
# 443         no_data         no_data  no_data                no_data
# 447         no_data         no_data  no_data                no_data
# 449         no_data         no_data  no_data                no_data
# 450         no_data         no_data  no_data                no_data
# 456         no_data         no_data  no_data                no_data
# 466         no_data         no_data  no_data                no_data
# 469         no_data         no_data  no_data                no_data
# 474         no_data         no_data  no_data                no_data
# 477         no_data         no_data  no_data                no_data
# 483         no_data         no_data  no_data                no_data
# 484         no_data         no_data  no_data                no_data
# 597         no_data         no_data  no_data                no_data
#
#      STUDY_CENTER EXPERIMENT_CENTER bmi_group_amish RUN_CENTER LATITUDE  \
# help
# 1         no_data           no_data               N    no_data  no_data
# 6         no_data           no_data               N    no_data  no_data
# 16        no_data           no_data               N    no_data  no_data
# 18        no_data           no_data               N    no_data  no_data
# 32        no_data           no_data               N    no_data  no_data
# 35        no_data           no_data               N    no_data  no_data
# 53        no_data           no_data               N    no_data  no_data
# 54        no_data           no_data               N    no_data  no_data
# 60        no_data           no_data               N    no_data  no_data
# 64        no_data           no_data               N    no_data  no_data
# 81        no_data           no_data               N    no_data  no_data
# 97        no_data           no_data               N    no_data  no_data
# 101       no_data           no_data               N    no_data  no_data
# 107       no_data           no_data               N    no_data  no_data
# 112       no_data           no_data               N    no_data  no_data
# 115       no_data           no_data               N    no_data  no_data
# 124       no_data           no_data               N    no_data  no_data
# 132       no_data           no_data               N    no_data  no_data
# 136       no_data           no_data               N    no_data  no_data
# 138       no_data           no_data               N    no_data  no_data
# 140       no_data           no_data               N    no_data  no_data
# 150       no_data           no_data               N    no_data  no_data
# 159       no_data           no_data               N    no_data  no_data
# 165       no_data           no_data               N    no_data  no_data
# 177       no_data           no_data               N    no_data  no_data
# 180       no_data           no_data               N    no_data  no_data
# 185       no_data           no_data               N    no_data  no_data
# 205       no_data           no_data               N    no_data  no_data
# 214       no_data           no_data               N    no_data  no_data
# 216       no_data           no_data               N    no_data  no_data
# ...           ...               ...             ...        ...      ...
# 380       no_data           no_data              OM    no_data  no_data
# 383       no_data           no_data              OB    no_data  no_data
# 384       no_data           no_data              OB    no_data  no_data
# 386       no_data           no_data              OB    no_data  no_data
# 389       no_data           no_data              OM    no_data  no_data
# 391       no_data           no_data              OM    no_data  no_data
# 396       no_data           no_data              OB    no_data  no_data
# 402       no_data           no_data              OM    no_data  no_data
# 403       no_data           no_data              OM    no_data  no_data
# 405       no_data           no_data              OM    no_data  no_data
# 412       no_data           no_data              OM    no_data  no_data
# 414       no_data           no_data              OB    no_data  no_data
# 417       no_data           no_data              OM    no_data  no_data
# 422       no_data           no_data              OB    no_data  no_data
# 431       no_data           no_data              OM    no_data  no_data
# 438       no_data           no_data              OB    no_data  no_data
# 439       no_data           no_data              OM    no_data  no_data
# 441       no_data           no_data              OM    no_data  no_data
# 443       no_data           no_data              OB    no_data  no_data
# 447       no_data           no_data              OM    no_data  no_data
# 449       no_data           no_data              OM    no_data  no_data
# 450       no_data           no_data              OB    no_data  no_data
# 456       no_data           no_data              OB    no_data  no_data
# 466       no_data           no_data              OM    no_data  no_data
# 469       no_data           no_data              OB    no_data  no_data
# 474       no_data           no_data              OM    no_data  no_data
# 477       no_data           no_data              OB    no_data  no_data
# 483       no_data           no_data              OM    no_data  no_data
# 484       no_data           no_data              OB    no_data  no_data
# 597       no_data           no_data              OM    no_data  no_data
#
#      Description
# help
# 1              1
# 6              6
# 16            16
# 18            18
# 32            32
# 35            35
# 53            53
# 54            54
# 60            60
# 64            64
# 81            81
# 97            97
# 101          101
# 107          107
# 112          112
# 115          115
# 124          124
# 132          132
# 136          136
# 138          138
# 140          140
# 150          150
# 159          159
# 165          165
# 177          177
# 180          180
# 185          185
# 205          205
# 214          214
# 216          216
# ...          ...
# 380          380
# 383          383
# 384          384
# 386          386
# 389          389
# 391          391
# 396          396
# 402          402
# 403          403
# 405          405
# 412          412
# 414          414
# 417          417
# 422          422
# 431          431
# 438          438
# 439          439
# 441          441
# 443          443
# 447          447
# 449          449
# 450          450
# 456          456
# 466          466
# 469          469
# 474          474
# 477          477
# 483          483
# 484          484
# 597          597
#
# [222 rows x 27 columns]

# %%
# prints 4th column
y = m.iloc[:, 4]
print(y)
print(y.size)
#i_copy[i_copy.bmi_group_binned == 3]
#i_copy.loc['bmi_group_binned'] = 0
#print(i_copy)
# Out:
# help
# 1      1
# 6      1
# 16     1
# 18     1
# 32     1
# 35     1
# 53     1
# 54     1
# 60     1
# 64     1
# 81     1
# 97     1
# 101    1
# 107    1
# 112    1
# 115    1
# 124    1
# 132    1
# 136    1
# 138    1
# 140    1
# 150    1
# 159    1
# 165    1
# 177    1
# 180    1
# 185    1
# 205    1
# 214    1
# 216    1
#       ..
# 385    2
# 398    2
# 401    2
# 406    2
# 408    2
# 415    2
# 416    2
# 420    2
# 423    2
# 428    2
# 429    2
# 437    2
# 444    2
# 445    2
# 452    2
# 459    2
# 460    2
# 464    2
# 467    2
# 470    2
# 471    2
# 473    2
# 475    2
# 476    2
# 481    2
# 482    2
# 488    2
# 595    2
# 598    2
# 599    2
# Name: bmi_group_binned, dtype: int64
# 325

# %%
p = pd.DataFrame(b.matrix_data.T.todense().astype(int), index=b.ids(axis="sample"), columns=b.ids(axis="observation"))
#p.reset_index(inplace=True)
print(p)
# Out:
#      304309  193008  190299  191393  193061  186596  174924  296166  177792  \
# 274       1       0       0       0       0       0       0       0      45
# 35        0       1       0       0       0       0       2       0       0
# 360       0       1       0       0       0       0       0       0       0
# 347       0       1       2       0       0       0       0       0       0
# 349       0       2       1       0       0       0       0       0       0
# 329       0       0       2       0       0       0       0       0      10
# 336       0       0       3       0       0       0       1       0       0
# 132       0       0       2       0       0       0       0       0      29
# 171       0       0       1       0       0       0       0       0       0
# 148       0       0       1       0       0       0       0       0       1
# 443       0       0       1       0       0       1       0       0       2
# 435       0       0       1       0       0       0       0       0       3
# 239       0       0      29       0       0       1       0       0      40
# 22        0       0      13       0       0       0       0       5       0
# 221       0       0       1       0       0       0       0       0       0
# 309       0       0      18       0       0       0       0       0       7
# 251       0       0       1       0       0       0       1       0       1
# 32         0       0      0
# 35         0       0      0
# 53         0       0      0
# 54         0       0      0
# 60         0       0      0
# 64         0       0      0
# 81         0       0      0
# 97         0       0      0
# 101        0       0      0
# 107        0       0      0
# 112        0       0      0
# 115        0       0      0
# 124        0       0      0
# 132        0       0      0
# 136        0       0      0
# 138        0       0      0
# 140        0       0      0
# 150        0       0      0
# 159        0       0      0
# 165        0       0      0
# 177        0       0      0
# 180        0       0      0
# 185        0       0      0
# 205        0       0      0
# 214        0       0      0
# 216        0       0      0
# ...      ...     ...    ...
# 380        0       0      0
# 383        0       0      0
# 384        0       0      0
# 386        0       0      0
# 389        0       0      0
# 391        0       0      0
# 396        0       0      0
# 402        0       0      0
# 403        0       0      0
# 405        0       0      0
# 412        0       0      0
# 414        0       0      0
# 417        0       0      0
# 422        0       0      0
# 431        0       0      0
# 438        0       0      0
# 439        0       0      0
# 441        0       0      0
# 443        0       0      0
# 447        0       0      0
# 449        0       0      0
# 450        0       0      0
# 456        0       0      0
# 466        0       0      0
# 469        0       0      0
# 474        0       0      0
# 477        0       0      0
# 483        0       0      0
# 484        0       0      0
# 597        0       0      0
#
# [222 rows x 27400 columns]

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
#10 fold cross-validation, 5 times repeated
#for i in range(5):
   # kfold = model_selection.KFold(n_splits=10, random_state=7)
    #model = RandomForestClassifier(n_estimators=1000)
    #results = model_selection.cross_val_score(model, p.fillna(0).as_matrix(), y, cv=kfold)
    #print(results.mean())

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
iter_range = range(1, 6)
# empty list to store scores
rForest_scores = []
average_accuracy = 0.0;

##for i in iter_range:
#    classifier = RandomForestClassifier(n_estimators=1000)
    #cross-validation score
    #scores = cross_val_score(classifier, c.fillna(0).as_matrix(), i_2.bmi_group_coded, cv=10, scoring='accuracy')
    
#    predicted = cross_val_predict(classifier, c.fillna(0).as_matrix(), i_2.bmi_group_binned, cv=10)
    
    #cross-validation AUC score
    #scores = cross_val_score(classifier, c.fillna(0).as_matrix(), i_2.bmi_group_binned, cv=10, scoring='roc_auc')
    #rForest_scores.append(scores.mean())
    #average_accuracy+=scores.mean()
    
#    print(confusion_matrix(i_2.bmi_group_binned, predicted))

#print(rForest_scores)
#print(average_accuracy/(5.0))

# %%
from sklearn.cross_validation import cross_val_score
iter_range = range(1, 6)
# empty list to store scores
rForest_scores = []
average_accuracy = 0.0;

for i in iter_range:
    classifier = RandomForestClassifier(n_estimators=1000)
    #cross-validation score
    #scores = cross_val_score(classifier, c.fillna(0).as_matrix(), i_2.bmi_group_coded, cv=10, scoring='accuracy')
    #cross-validation AUC score
    scores = cross_val_score(classifier, c.fillna(0).as_matrix(), i_2.bmi_group_binned, cv=10, scoring='roc_auc')
    rForest_scores.append(scores.mean())
    average_accuracy+=scores.mean()

# %%
print(rForest_scores)
print(average_accuracy/(5.0))
# Out:
# [0.6540476190476191, 0.64147108843537404, 0.6490476190476191, 0.64344387755102039, 0.6462244897959184]
# 0.646846938776
